# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

# %%
DRIVER = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - Downloading: 100%|██████████| 8.29M/8.29M [00:00<00:00, 28.1MB/s]

# %%
FBREF_HOMEPAGE_URL = "https://fbref.com/"
PREM_URL = "https://fbref.com/en/comps/9/Premier-League-Stats"
LEAGUE_TEAM_TABLE_ID = "results2022-202391_overall"

# %%
player_name = "douglas luiz"
player_team = "aston villa"

# %%
def get_full_url(url_tail):
    return urljoin(FBREF_HOMEPAGE_URL, url_tail)


def get_table_info(url, driver, table_tag_id = "matchlogs_for"):
    # Load the page using Selenium
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)
    table_wait = wait.until(EC.presence_of_element_located((By.ID, table_tag_id)))

    # create a Beautiful Soup object from the response content
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # find the table with id 'div_matchlogs_for'
    table = soup.find('table', {'id': table_tag_id})

    return table

def get_teams_urls(table):
    # extract the table rows
    rows = table.find_all('tr')

    # extract the data from each row and store it in a list
    url_data = []
    i = 0
    for row in rows:
        i += 1
        team_cell = row.find('td', {'data-stat': 'team'})
        if team_cell:
            team_name = team_cell.find("a").text
            team_url_tail = team_cell.find("a")['href']
            team_uid = team_url_tail.split("/")[3]
            team_url = get_full_url(team_url_tail)
            url_data.append({"Team Name": team_name, "Unique ID": team_uid, "URL Link": team_url})
 
    df = pd.DataFrame(url_data)
    return df

# %%
table_prem_teams = get_table_info(PREM_URL, DRIVER, table_tag_id = LEAGUE_TEAM_TABLE_ID)
df_team_urls = get_teams_urls(table_prem_teams)

# %%
df_team_urls
# Out:
#           Team Name Unique ID  \
# 0   Manchester City  b8fd03ef
# 1           Arsenal  18bb7c10
# 2    Manchester Utd  19538871
# 3     Newcastle Utd  b2b47a98
# 4         Liverpool  822bd0ba
# 5          Brighton  d07537b9
# 6       Aston Villa  8602292d
# 7         Tottenham  361ca564
# 8         Brentford  cd051869
# 9            Fulham  fd962109
# 10   Crystal Palace  47c64c55
# 11          Chelsea  cff3d9bb
# 12           Wolves  8cec06e1
# 13         West Ham  7c21e445
# 14      Bournemouth  4ba7cbea
# 15  Nott'ham Forest  e4a775cb
# 16          Everton  d3fd31cc
# 17   Leicester City  a2d435b3
# 18     Leeds United  5bfb9659
# 19      Southampton  33c895d4
#
#                                              URL Link
# 0   https://fbref.com/en/squads/b8fd03ef/Mancheste...
# 1   https://fbref.com/en/squads/18bb7c10/Arsenal-S...
# 2   https://fbref.com/en/squads/19538871/Mancheste...
# 3   https://fbref.com/en/squads/b2b47a98/Newcastle...
# 4   https://fbref.com/en/squads/822bd0ba/Liverpool...
# 5   https://fbref.com/en/squads/d07537b9/Brighton-...
# 6   https://fbref.com/en/squads/8602292d/Aston-Vil...
# 7   https://fbref.com/en/squads/361ca564/Tottenham...
# 8   https://fbref.com/en/squads/cd051869/Brentford...
# 9   https://fbref.com/en/squads/fd962109/Fulham-Stats
# 10  https://fbref.com/en/squads/47c64c55/Crystal-P...
# 11  https://fbref.com/en/squads/cff3d9bb/Chelsea-S...
# 12  https://fbref.com/en/squads/8cec06e1/Wolverham...
# 13  https://fbref.com/en/squads/7c21e445/West-Ham-...
# 14  https://fbref.com/en/squads/4ba7cbea/Bournemou...
# 15  https://fbref.com/en/squads/e4a775cb/Nottingha...
# 16  https://fbref.com/en/squads/d3fd31cc/Everton-S...
# 17  https://fbref.com/en/squads/a2d435b3/Leicester...
# 18  https://fbref.com/en/squads/5bfb9659/Leeds-Uni...
# 19  https://fbref.com/en/squads/33c895d4/Southampt...

# %%
def get_team_matches(table):
    # Get the table headers
    headers = [header.text for header in table.find_all('th')]
    headers_front = headers[:19]
    headers_date = headers[19:]
    
    # Get the table rows
    rows = table.find_all('tr')
    
    table_data = []
    row_index = 0
    for row in rows[1:]:  # We skip the first row, because it contains the headers
        row_data = []
        cells = row.find_all('td')
        # get URLs for team names (position 8 from Time column onwards) and for Match reports (position -2 from back)
        row_data = [cell.text.strip() if i != len(cells)-2 and i != 8 else get_full_url(cell.find('a')["href"]) for i, cell in enumerate(cells)]

        row_data.insert(0, str(headers_date[row_index]))
        table_data.append(row_data)
        row_index += 1
    
    # Create a pandas DataFrame from the scraped data
    df = pd.DataFrame(table_data, columns=headers_front)
    return df

# %%
table_team_matches = get_table_info("https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats", DRIVER, table_tag_id = "matchlogs_for")
df_team_matches = get_team_matches(table_team_matches) # need to indicate the team i am scraping for in the table.

# %%
df_team_matches.head(3)
# Out:
#          Date           Time              Comp                Round  Day  \
# 0  2022-07-30  17:00 (00:00)  Community Shield  FA Community Shield  Sat
# 1  2022-08-07  16:30 (23:30)    Premier League          Matchweek 1  Sun
# 2  2022-08-13  15:00 (22:00)    Premier League          Matchweek 2  Sat
#
#      Venue Result GF GA                                           Opponent  \
# 0  Neutral      L  1  3  https://fbref.com/en/squads/822bd0ba/Liverpool...
# 1     Away      W  2  0  https://fbref.com/en/squads/7c21e445/West-Ham-...
# 2     Home      W  4  0  https://fbref.com/en/squads/4ba7cbea/Bournemou...
#
#     xG  xGA Poss Attendance         Captain Formation         Referee  \
# 0             57                 Rúben Dias     4-3-3    Craig Pawson
# 1  2.2  0.5   75     62,443  İlkay Gündoğan     4-3-3  Michael Oliver
# 2  1.7  0.1   67     53,453  İlkay Gündoğan   4-2-3-1     David Coote
#
#                                         Match Report Notes
# 0  https://fbref.com/en/matches/341bf7a1/Liverpoo...
# 1  https://fbref.com/en/matches/ece62baf/West-Ham...
# 2  https://fbref.com/en/matches/311d705c/Manchest...

# %%
df_team_matches["Match Report"][3]
# Out:
# 'https://fbref.com/en/matches/b513d9fe/Newcastle-United-Manchester-City-August-21-2022-Premier-League'

# %%
def load_scorebox_soup(url, driver, tag_id = "scorebox"):
    # Load the page using Selenium
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)
    wait.until(EC.presence_of_element_located((By.CLASS_NAME, tag_id)))

    # create a Beautiful Soup object from the response content
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    return soup


def get_teams_playing_uids(soup):    
    # find the div with id 'scorebox'
    div = soup.find('div', {'class': "scorebox"})

    divs = div.find_all("div", recursive=False, limit=2)
    home_team_div, away_team_div = divs[0], divs[1]
    home_team_uid = home_team_div.find('a')['href'].split('/')[3]
    away_team_uid = away_team_div.find('a')['href'].split('/')[3]

    return [home_team_uid, away_team_uid]

# %%
sb_soup = load_scorebox_soup("https://fbref.com/en/matches/dff22d13/Newcastle-United-Tottenham-Hotspur-April-23-2023-Premier-League", DRIVER)
team_uids = get_teams_playing_uids(sb_soup) # home_team_uid, away_team_uid

# %%
team_uids
# Out:
# ['b2b47a98', '361ca564']

# %%
def load_outfield_perf_soup(uids, url, driver):
    # Load the page using Selenium
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)    
    wait.until(EC.presence_of_element_located((By.ID, f"stats_{uids[0]}_summary")))
    wait.until(EC.presence_of_element_located((By.ID, f"stats_{uids[1]}_summary")))

    # create a Beautiful Soup object from the response content
    soup = BeautifulSoup(DRIVER.page_source, 'html.parser')
    return soup

def get_outfield_perf(team_uids, soup):

    df_list = []
    # find the div with id 'stats_teamuid_summary'
    for team_uid in team_uids:
        table = soup.find('table', {'id': f"stats_{team_uid}_summary"})

        data = []
        table_headers = table.find_all('th')

        # retrive column headers (aka names of the statistics)
        first_index_stat_header = 7
        last_index_stat_header = 37
        col_stats_names = [header.get('aria-label') for header in table_headers][first_index_stat_header:(last_index_stat_header + 1)] # ignore 0-6, take 7-37
        col_stats_names.insert(0, "player_uid")
        col_stats_names.insert(0, "team_uid")

        # retrieve player names
        player_info = table_headers[(last_index_stat_header + 1):-1] # omit the last row since its an aggregation row.
        player_names = [player.get_text().strip() for player in player_info]
        player_uid = [player.find('a')['href'].split('/')[3] for player in player_info]
        
        table_body = table.find('tbody')

        rows = table_body.find_all('tr')
        row_index = 0
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            cols.insert(0, player_names[row_index])
            cols.insert(0, player_uid[row_index])
            cols.insert(0, team_uid)
            row_index += 1
            data.append(cols)

        # Convert data to DataFrame
        df = pd.DataFrame(data, columns = col_stats_names)
        df_list.append(df)

    final_match_df = pd.concat(df_list, ignore_index=True)
    return final_match_df

# %%
soup_outfield_perf = load_outfield_perf_soup(team_uids, "https://fbref.com/en/matches/dff22d13/Newcastle-United-Tottenham-Hotspur-April-23-2023-Premier-League", DRIVER)
final_match_df = get_outfield_perf(team_uids, soup_outfield_perf)

# %%
final_match_df
# Out:
#     team_uid player_uid            Player Shirt Number   Nation Position  \
# 0   b2b47a98   8e92be30    Alexander Isak           14   se SWE       FW
# 1   b2b47a98   c596fcb0     Callum Wilson            9  eng ENG       FW
# 2   b2b47a98   c17bfb65         Joelinton            7   br BRA    LW,CM
# 3   b2b47a98   de112b84      Jacob Murphy           23  eng ENG       RW
# 4   b2b47a98   862a1c15    Miguel Almirón           24   py PAR       RW
# 5   b2b47a98   a3b03921       Joe Willock           28  eng ENG       LM
# 6   b2b47a98   82518f62   Bruno Guimarães           39   br BRA       CM
# 7   b2b47a98   2bd83368    Anthony Gordon            8  eng ENG       LW
# 8   b2b47a98   a2b105e0    Sean Longstaff           36  eng ENG       RM
# 9   b2b47a98   b2d31e83          Dan Burn           33  eng ENG       LB
# 10  b2b47a98   ccce7025       Sven Botman            4   nl NED       CB
# 11  b2b47a98   c8aa95da      Fabian Schär            5   ch SUI       CB
# 12  b2b47a98   450ab6fc  Jamaal Lascelles            6  eng ENG       CB
# 13  b2b47a98   21512407   Kieran Trippier            2  eng ENG       RB
# 14  b2b47a98   758dd7f0  Javier Manquillo           19   es ESP       RB
# 15  b2b47a98   4b40d9ca         Nick Pope           22  eng ENG       GK
# 16  361ca564   21a66f6a        Harry Kane           10  eng ENG       FW
# 17  361ca564   92e7e919     Son Heung-min            7   kr KOR    LW,RW
# 18  361ca564   fa031b34       Richarlison            9   br BRA       RW
# 19  361ca564   df3cda47  Dejan Kulusevski           21   se SWE       RW
# 20  361ca564   f08490a6    Arnaut Danjuma           16   nl NED       LW
# 21  361ca564   8b04d6c1   Pierre Højbjerg            5   dk DEN    CM,LM
# 22  361ca564   6250083a      Oliver Skipp            4  eng ENG       CM
# 23  361ca564   feb5d972   Pape Matar Sarr           29   sn SEN       RM
# 24  361ca564   da7b447d  Davinson Sánchez            6   co COL       CB
# 25  361ca564   6fe90922      Ivan Perišić           14   hr CRO    LM,LB
# 26  361ca564   ac861941         Eric Dier           15  eng ENG       CB
# 27  361ca564   a3d94a58   Cristian Romero           17   ar ARG       CB
# 28  361ca564   27d0a506       Pedro Porro           23   es ESP    RM,RB
# 29  361ca564   8f62b6ee       Hugo Lloris            1   fr FRA       GK
# 30  361ca564   c3e39f12    Fraser Forster           20  eng ENG       GK
#
#        Age Minutes Goals Assists  ... Shot-Creating Actions  \
# 0   23-214      65     2       0  ...                     2
# 1   31-055      25     1       0  ...                     1
# 2   26-252      90     1       0  ...                     7
# 3   28-058      65     2       0  ...                     4
# 4   29-072      25     0       0  ...                     2
# 5   23-246      90     0       1  ...                     4
# 6   25-158      69     0       0  ...                     9
# 7   22-058      21     0       0  ...                     2
# 8   25-175      90     0       1  ...                     4
# 9   30-349      90     0       0  ...                     1
# 10  23-101      90     0       0  ...                     0
# 11  31-124      73     0       2  ...                     2
# 12  29-163      17     0       0  ...                     1
# 13  32-216      69     0       0  ...                     5
# 14  28-353      21     0       0  ...                     0
# 15  31-004      90     0       0  ...                     0
# 16  29-269      90     1       0  ...                     1
# 17  30-289      82     0       0  ...                     3
# 18  25-348       8     0       0  ...                     2
# 19  22-363      71     0       0  ...                     4
# 20  26-082      19     0       0  ...                     0
# 21  27-261      90     0       1  ...                     2
# 22  22-219      90     0       0  ...                     2
# 23  20-221      22     0       0  ...                     0
# 24  26-315      68     0       0  ...                     0
# 25  34-080      90     0       0  ...                     1
# 26  29-098      90     0       0  ...                     1
# 27  24-361      90     0       0  ...                     2
# 28  23-222      90     0       0  ...                     2
# 29  36-118      45     0       0  ...                     0
# 30  35-037      45     0       0  ...                     0
#
#    Goal-Creating Actions Passes Completed Passes Attempted Pass Completion %  \
# 0                      0               14               17              82.4
# 1                      0                4                4             100.0
# 2                      2               54               60              90.0
# 3                      1               15               24              62.5
# 4                      1               14               18              77.8
# 5                      1               42               48              87.5
# 6                      1               62               71              87.3
# 7                      0               12               13              92.3
# 8                      1               34               35              97.1
# 9                      0               48               60              80.0
# 10                     0               47               49              95.9
# 11                     2               31               40              77.5
# 12                     0               14               14             100.0
# 13                     0               51               65              78.5
# 14                     0               17               18              94.4
# 15                     0               14               21              66.7
# 16                     1               17               24              70.8
# 17                     0               12               16              75.0
# 18                     0                1                2              50.0
# 19                     0               22               22             100.0
# 20                     0                2                4              50.0
# 21                     1               48               57              84.2
# 22                     0               42               43              97.7
# 23                     0               15               16              93.8
# 24                     0               24               30              80.0
# 25                     0               19               29              65.5
# 26                     0               41               55              74.5
# 27                     0               44               49              89.8
# 28                     0               38               56              67.9
# 29                     0                7               13              53.8
# 30                     0                8               16              50.0
#
#    Progressive Passes Carries Progressive Carries Take-Ons Attempted  \
# 0                   2      21                   1                  3
# 1                   0       5                   0                  2
# 2                   5      52                   5                  8
# 3                   5      25                   3                  2
# 4                   0      17                   2                  1
# 5                   4      42                   5                  5
# 6                  13      66                   1                  3
# 7                   2      14                   1                  0
# 8                   2      35                   0                  1
# 9                   2      42                   0                  2
# 10                  4      36                   0                  0
# 11                  3      29                   1                  0
# 12                  0      12                   0                  0
# 13                  6      44                   2                  1
# 14                  3      13                   0                  0
# 15                  0      12                   0                  0
# 16                  3      25                   3                  1
# 17                  1      16                   1                  3
# 18                  0       1                   1                  1
# 19                  2      16                   1                  3
# 20                  0       2                   0                  0
# 21                  4      38                   1                  3
# 22                  1      30                   3                  1
# 23                  0      12                   0                  0
# 24                  1      21                   1                  2
# 25                  1      17                   2                  2
# 26                  2      32                   0                  1
# 27                  0      30                   0                  0
# 28                  2      22                   4                  0
# 29                  0       6                   0                  0
# 30                  0       8                   0                  0
#
#    Successful Take-Ons
# 0                    2
# 1                    2
# 2                    5
# 3                    1
# 4                    0
# 5                    3
# 6                    1
# 7                    0
# 8                    0
# 9                    1
# 10                   0
# 11                   0
# 12                   0
# 13                   1
# 14                   0
# 15                   0
# 16                   1
# 17                   1
# 18                   1
# 19                   3
# 20                   0
# 21                   2
# 22                   1
# 23                   0
# 24                   1
# 25                   2
# 26                   0
# 27                   0
# 28                   0
# 29                   0
# 30                   0
#
# [31 rows x 33 columns]

# %%
# need code that specifically only scrapes a list of URL/matches to update the DB every week or so.

# %%
def load_keeper_perf_soup(uids, url, driver):
    # Load the page using Selenium
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)    
    wait.until(EC.presence_of_element_located((By.ID, f"keeper_stats_{uids[0]}")))
    wait.until(EC.presence_of_element_located((By.ID, f"keeper_stats_{uids[1]}")))

    # create a Beautiful Soup object from the response content
    soup = BeautifulSoup(DRIVER.page_source, 'html.parser')
    return soup

def get_keeper_perf(team_uids, soup):

    df_list = []
    # find the div with id 'keeper_stats_{team_uid}'
    for team_uid in team_uids:
        table = soup.find('table', {'id': f"keeper_stats_{team_uid}"})

        data = []
        table_headers = table.find_all('th')

        # retrive column headers (aka names of the statistics)
        first_index_stat_header = 7
        last_index_stat_header = 30
        col_stats_names = [header.get('aria-label') for header in table_headers][first_index_stat_header:(last_index_stat_header + 1)] # ignore 0-6, take 7-30
        col_stats_names.insert(0, "player_uid")
        col_stats_names.insert(0, "team_uid")

        # retrieve player names
        player_info = table_headers[(last_index_stat_header + 1):] # retrieve all keepers that played
        player_names = [player.get_text().strip() for player in player_info]

        table_body = table.find('tbody')

        rows = table_body.find_all('tr')
        row_index = 0
        for row in rows:
            cols = row.find_all('td')
            player_uid = row.find('th', {'data-stat': "player"}).get('data-append-csv').strip()
            cols = [ele.text.strip() for ele in cols]
            cols.insert(0, player_names[row_index])
            cols.insert(0, player_uid)
            cols.insert(0, team_uid)
            row_index += 1
            data.append(cols)

        # Convert data to DataFrame
        df = pd.DataFrame(data, columns = col_stats_names)
        df_list.append(df)

    final_match_df = pd.concat(df_list, ignore_index=True)
    return final_match_df

# %%
def load_match_soup(url, driver, tag_id = "scorebox"):
    # Load the page using Selenium
    driver.get(url)
    
    wait = WebDriverWait(driver, 10)    

    # waiting till scorebox appears
    wait.until(EC.presence_of_element_located((By.CLASS_NAME, tag_id)))

    # wait until at least two elements with id starting with 'div_stats_' are present in the DOM
    wait.until(lambda d: len(d.find_elements(By.CSS_SELECTOR, "[id^='stats_'][id$='_summary']"))>=2)

    # wait.until(EC.presence_of_element_located((By.ID, f"stats_{uids[0]}_summary")))
    # wait.until(EC.presence_of_element_located((By.ID, f"stats_{uids[1]}_summary")))

    wait.until(lambda d: len(d.find_elements(By.CSS_SELECTOR, "[id^='keeper_stats_']"))>=2)
    
    # wait.until(EC.presence_of_element_located((By.ID, f"keeper_stats_{uids[0]}")))
    # wait.until(EC.presence_of_element_located((By.ID, f"keeper_stats_{uids[1]}")))

    # create a Beautiful Soup object from the response content
    soup = BeautifulSoup(DRIVER.page_source, 'html.parser')
    return soup

# %%
keeper_soup = load_keeper_perf_soup(team_uids, "https://fbref.com/en/matches/dff22d13/Newcastle-United-Tottenham-Hotspur-April-23-2023-Premier-League", DRIVER)
keepers_df = get_keeper_perf(team_uids, keeper_soup)
# Out:
# 26
# 26

# %%
keepers_df
# Out:
#    team_uid player_uid          Player   Nation     Age Minutes  \
# 0  b2b47a98   4b40d9ca       Nick Pope  eng ENG  31-004      90
# 1  361ca564   8f62b6ee     Hugo Lloris   fr FRA  36-118      45
# 2  361ca564   c3e39f12  Fraser Forster  eng ENG  35-037      45
#
#   Shots on Target Against Goals Against Saves Save Percentage  ... Launch %  \
# 0                       3             1     2            66.7  ...     30.8
# 1                       6             5     1            16.7  ...     63.6
# 2                       2             1     1            50.0  ...     46.2
#
#   Average Pass Length Goal Kicks Launch% (Goal Kicks)  \
# 0                33.2          8                 87.5
# 1                43.5          2                100.0
# 2                37.8          3                 66.7
#
#   Avg. Length of Goal Kicks Crosses Faced Crosses Stopped Crosses Stopped %  \
# 0                      62.3             4               0               0.0
# 1                      66.5             9               1              11.1
# 2                      47.7             5               0               0.0
#
#   Def. Actions Outside Pen. Area Avg. Distance of Def. Actions
# 0                              1                          30.0
# 1                                                          8.0
# 2                              0
#
# [3 rows x 26 columns]

# %%
match_soup = load_match_soup("https://fbref.com/en/matches/dff22d13/Newcastle-United-Tottenham-Hotspur-April-23-2023-Premier-League", DRIVER, tag_id = "scorebox")

# %%
def retrieve_match_soup_info(match_soup):
    team_uids = get_teams_playing_uids(match_soup)
    outfield_df_whole = get_outfield_perf(team_uids, match_soup)
    keeper_df_whole = get_keeper_perf(team_uids, match_soup)
    return [outfield_df_whole, keeper_df_whole]

# %%
outfield_df_whole, keeper_df_whole = retrieve_match_soup_info(match_soup)

# %%
outfield_df_whole
# Out:
#     team_uid player_uid            Player Shirt Number   Nation Position  \
# 0   b2b47a98   8e92be30    Alexander Isak           14   se SWE       FW
# 1   b2b47a98   c596fcb0     Callum Wilson            9  eng ENG       FW
# 2   b2b47a98   c17bfb65         Joelinton            7   br BRA    LW,CM
# 3   b2b47a98   de112b84      Jacob Murphy           23  eng ENG       RW
# 4   b2b47a98   862a1c15    Miguel Almirón           24   py PAR       RW
# 5   b2b47a98   a3b03921       Joe Willock           28  eng ENG       LM
# 6   b2b47a98   82518f62   Bruno Guimarães           39   br BRA       CM
# 7   b2b47a98   2bd83368    Anthony Gordon            8  eng ENG       LW
# 8   b2b47a98   a2b105e0    Sean Longstaff           36  eng ENG       RM
# 9   b2b47a98   b2d31e83          Dan Burn           33  eng ENG       LB
# 10  b2b47a98   ccce7025       Sven Botman            4   nl NED       CB
# 11  b2b47a98   c8aa95da      Fabian Schär            5   ch SUI       CB
# 12  b2b47a98   450ab6fc  Jamaal Lascelles            6  eng ENG       CB
# 13  b2b47a98   21512407   Kieran Trippier            2  eng ENG       RB
# 14  b2b47a98   758dd7f0  Javier Manquillo           19   es ESP       RB
# 15  b2b47a98   4b40d9ca         Nick Pope           22  eng ENG       GK
# 16  361ca564   21a66f6a        Harry Kane           10  eng ENG       FW
# 17  361ca564   92e7e919     Son Heung-min            7   kr KOR    LW,RW
# 18  361ca564   fa031b34       Richarlison            9   br BRA       RW
# 19  361ca564   df3cda47  Dejan Kulusevski           21   se SWE       RW
# 20  361ca564   f08490a6    Arnaut Danjuma           16   nl NED       LW
# 21  361ca564   8b04d6c1   Pierre Højbjerg            5   dk DEN    CM,LM
# 22  361ca564   6250083a      Oliver Skipp            4  eng ENG       CM
# 23  361ca564   feb5d972   Pape Matar Sarr           29   sn SEN       RM
# 24  361ca564   da7b447d  Davinson Sánchez            6   co COL       CB
# 25  361ca564   6fe90922      Ivan Perišić           14   hr CRO    LM,LB
# 26  361ca564   ac861941         Eric Dier           15  eng ENG       CB
# 27  361ca564   a3d94a58   Cristian Romero           17   ar ARG       CB
# 28  361ca564   27d0a506       Pedro Porro           23   es ESP    RM,RB
# 29  361ca564   8f62b6ee       Hugo Lloris            1   fr FRA       GK
# 30  361ca564   c3e39f12    Fraser Forster           20  eng ENG       GK
#
#        Age Minutes Goals Assists  ... Shot-Creating Actions  \
# 0   23-214      65     2       0  ...                     2
# 1   31-055      25     1       0  ...                     1
# 2   26-252      90     1       0  ...                     7
# 3   28-058      65     2       0  ...                     4
# 4   29-072      25     0       0  ...                     2
# 5   23-246      90     0       1  ...                     4
# 6   25-158      69     0       0  ...                     9
# 7   22-058      21     0       0  ...                     2
# 8   25-175      90     0       1  ...                     4
# 9   30-349      90     0       0  ...                     1
# 10  23-101      90     0       0  ...                     0
# 11  31-124      73     0       2  ...                     2
# 12  29-163      17     0       0  ...                     1
# 13  32-216      69     0       0  ...                     5
# 14  28-353      21     0       0  ...                     0
# 15  31-004      90     0       0  ...                     0
# 16  29-269      90     1       0  ...                     1
# 17  30-289      82     0       0  ...                     3
# 18  25-348       8     0       0  ...                     2
# 19  22-363      71     0       0  ...                     4
# 20  26-082      19     0       0  ...                     0
# 21  27-261      90     0       1  ...                     2
# 22  22-219      90     0       0  ...                     2
# 23  20-221      22     0       0  ...                     0
# 24  26-315      68     0       0  ...                     0
# 25  34-080      90     0       0  ...                     1
# 26  29-098      90     0       0  ...                     1
# 27  24-361      90     0       0  ...                     2
# 28  23-222      90     0       0  ...                     2
# 29  36-118      45     0       0  ...                     0
# 30  35-037      45     0       0  ...                     0
#
#    Goal-Creating Actions Passes Completed Passes Attempted Pass Completion %  \
# 0                      0               14               17              82.4
# 1                      0                4                4             100.0
# 2                      2               54               60              90.0
# 3                      1               15               24              62.5
# 4                      1               14               18              77.8
# 5                      1               42               48              87.5
# 6                      1               62               71              87.3
# 7                      0               12               13              92.3
# 8                      1               34               35              97.1
# 9                      0               48               60              80.0
# 10                     0               47               49              95.9
# 11                     2               31               40              77.5
# 12                     0               14               14             100.0
# 13                     0               51               65              78.5
# 14                     0               17               18              94.4
# 15                     0               14               21              66.7
# 16                     1               17               24              70.8
# 17                     0               12               16              75.0
# 18                     0                1                2              50.0
# 19                     0               22               22             100.0
# 20                     0                2                4              50.0
# 21                     1               48               57              84.2
# 22                     0               42               43              97.7
# 23                     0               15               16              93.8
# 24                     0               24               30              80.0
# 25                     0               19               29              65.5
# 26                     0               41               55              74.5
# 27                     0               44               49              89.8
# 28                     0               38               56              67.9
# 29                     0                7               13              53.8
# 30                     0                8               16              50.0
#
#    Progressive Passes Carries Progressive Carries Take-Ons Attempted  \
# 0                   2      21                   1                  3
# 1                   0       5                   0                  2
# 2                   5      52                   5                  8
# 3                   5      25                   3                  2
# 4                   0      17                   2                  1
# 5                   4      42                   5                  5
# 6                  13      66                   1                  3
# 7                   2      14                   1                  0
# 8                   2      35                   0                  1
# 9                   2      42                   0                  2
# 10                  4      36                   0                  0
# 11                  3      29                   1                  0
# 12                  0      12                   0                  0
# 13                  6      44                   2                  1
# 14                  3      13                   0                  0
# 15                  0      12                   0                  0
# 16                  3      25                   3                  1
# 17                  1      16                   1                  3
# 18                  0       1                   1                  1
# 19                  2      16                   1                  3
# 20                  0       2                   0                  0
# 21                  4      38                   1                  3
# 22                  1      30                   3                  1
# 23                  0      12                   0                  0
# 24                  1      21                   1                  2
# 25                  1      17                   2                  2
# 26                  2      32                   0                  1
# 27                  0      30                   0                  0
# 28                  2      22                   4                  0
# 29                  0       6                   0                  0
# 30                  0       8                   0                  0
#
#    Successful Take-Ons
# 0                    2
# 1                    2
# 2                    5
# 3                    1
# 4                    0
# 5                    3
# 6                    1
# 7                    0
# 8                    0
# 9                    1
# 10                   0
# 11                   0
# 12                   0
# 13                   1
# 14                   0
# 15                   0
# 16                   1
# 17                   1
# 18                   1
# 19                   3
# 20                   0
# 21                   2
# 22                   1
# 23                   0
# 24                   1
# 25                   2
# 26                   0
# 27                   0
# 28                   0
# 29                   0
# 30                   0
#
# [31 rows x 33 columns]

# %%
keeper_df_whole
# Out:
#    team_uid player_uid          Player   Nation     Age Minutes  \
# 0  b2b47a98   4b40d9ca       Nick Pope  eng ENG  31-004      90
# 1  361ca564   8f62b6ee     Hugo Lloris   fr FRA  36-118      45
# 2  361ca564   c3e39f12  Fraser Forster  eng ENG  35-037      45
#
#   Shots on Target Against Goals Against Saves Save Percentage  ... Launch %  \
# 0                       3             1     2            66.7  ...     30.8
# 1                       6             5     1            16.7  ...     63.6
# 2                       2             1     1            50.0  ...     46.2
#
#   Average Pass Length Goal Kicks Launch% (Goal Kicks)  \
# 0                33.2          8                 87.5
# 1                43.5          2                100.0
# 2                37.8          3                 66.7
#
#   Avg. Length of Goal Kicks Crosses Faced Crosses Stopped Crosses Stopped %  \
# 0                      62.3             4               0               0.0
# 1                      66.5             9               1              11.1
# 2                      47.7             5               0               0.0
#
#   Def. Actions Outside Pen. Area Avg. Distance of Def. Actions
# 0                              1                          30.0
# 1                                                          8.0
# 2                              0
#
# [3 rows x 26 columns]

# %%
DRIVER.quit()
